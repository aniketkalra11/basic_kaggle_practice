# %% [markdown]
# Graded assignment 2

# %%
import pandas as pd
import numpy as np

# %%
data_file = pd.read_csv('V5.csv')

# %%
data_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               10000 non-null  object
#  1   Year               10000 non-null  int64
#  2   Locality           8747 non-null   object
#  3   Estimated Value    8757 non-null   float64
#  4   Sale Price         10000 non-null  float64
#  5   Property           10000 non-null  object
#  6   Residential        10000 non-null  object
#  7   num_rooms          10000 non-null  int64
#  8   num_bathrooms      10000 non-null  int64
#  9   carpet_area        8771 non-null   float64
#  10  property_tax_rate  10000 non-null  float64
#  11  Face               10000 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 937.6+ KB

# %%
data_file.isna().sum()
# Out:
# Date                    0
# Year                    0
# Locality             1253
# Estimated Value      1243
# Sale Price              0
# Property                0
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1229
# property_tax_rate       0
# Face                    0
# dtype: int64

# %%
filtered_data_file = data_file.replace('?', np.nan)

# %%
filtered_data_file.isna().sum()
# Out:
# Date                    0
# Year                    0
# Locality             1253
# Estimated Value      1243
# Sale Price              0
# Property             1823
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1229
# property_tax_rate       0
# Face                    0
# dtype: int64

# %%
filtered_data_file
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 1     2009-01-02  2009  Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009   Waterbury          55720.0    140000.0
# 3     2009-01-02  2009  Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009  Bridgeport         112351.0    210000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
filtered_data_file.shape
# Out:
# (10000, 12)

# %%
filtered_data_file.loc[692][0]
# Out:
# '2009-11-16'

# %%
filtered_data_file.loc[546][7]
# Out:
# 3

# %%
filtered_data_file.Locality.unique()
# Out:
# array(['Waterbury', 'Bridgeport', 'Greenwich', 'Norwalk', nan,
#        'Fairfield', 'West Hartford', 'Stamford'], dtype=object)

# %%
filtered_data_file.isna().sum()
# Out:
# Date                    0
# Year                    0
# Locality             1253
# Estimated Value      1243
# Sale Price              0
# Property             1823
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1229
# property_tax_rate       0
# Face                    0
# dtype: int64

# %%
filter_after_drop = filtered_data_file.dropna(axis=0, thresh=10)

# %%
filter_after_drop.isna().sum()
# Out:
# Date                    0
# Year                    0
# Locality             1192
# Estimated Value      1173
# Sale Price              0
# Property             1762
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1172
# property_tax_rate       0
# Face                    0
# dtype: int64

# %%
filter_after_drop.shape
# Out:
# (9917, 12)

# %%
fileter_data_drop_2 = filtered_data_file.dropna(axis=0, how='any')
fileter_data_drop_2.shape
# Out:
# (5449, 12)

# %% [markdown]
# ### Graded assignment week2.2

# %%
even_rows = data_file.iloc[::2]
even_rows.shape
# Out:
# (5000, 12)

# %%
even_rows.loc[0][3]
# Out:
# 111440.0

# %%
even_rows.loc[332][3]
# Out:
# 862890.0

# %%
odd_rows = data_file[1::2]
odd_rows.shape
# Out:
# (5000, 12)

# %%
even_rows.iloc[0]
# Out:
# Date                     2009-01-02
# Year                           2009
# Locality                  Waterbury
# Estimated Value            111440.0
# Sale Price                 185000.0
# Property              Single Family
# Residential          Detached House
# num_rooms                         3
# num_bathrooms                     3
# carpet_area                   996.0
# property_tax_rate          1.025953
# Face                          South
# Name: 0, dtype: object

# %%
odd_rows.iloc[0]
# Out:
# Date                 2009-01-02
# Year                       2009
# Locality             Bridgeport
# Estimated Value        124670.0
# Sale Price             150000.0
# Property             Two Family
# Residential              Duplex
# num_rooms                     4
# num_bathrooms                 3
# carpet_area              1241.0
# property_tax_rate      1.025953
# Face                      South
# Name: 1, dtype: object

# %%
data_file.iloc[0]
# Out:
# Date                     2009-01-02
# Year                           2009
# Locality                  Waterbury
# Estimated Value            111440.0
# Sale Price                 185000.0
# Property              Single Family
# Residential          Detached House
# num_rooms                         3
# num_bathrooms                     3
# carpet_area                   996.0
# property_tax_rate          1.025953
# Face                          South
# Name: 0, dtype: object

# %%
data_file.iloc[1]
# Out:
# Date                 2009-01-02
# Year                       2009
# Locality             Bridgeport
# Estimated Value        124670.0
# Sale Price             150000.0
# Property             Two Family
# Residential              Duplex
# num_rooms                     4
# num_bathrooms                 3
# carpet_area              1241.0
# property_tax_rate      1.025953
# Face                      South
# Name: 1, dtype: object

# %%
odd_rows.iloc[332][3]
# Out:
# 352940.0

# %%
odd_cols = data_file

# %%
data_file.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %%
odd_cols = data_file.iloc[:, 1::2]

# %%
odd_cols.iloc[100][5]
# Out:
# 'West'

# %%
even_cols = data_file.iloc[:, ::2]
even_cols.iloc[255][3]
# Out:
# 'Detached House'

# %%
resultant_years = [x for x in range(2017, 2023)]
q6 = data_file[data_file.Year.isin(resultant_years)]
q6
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 5251  2017-01-02  2017   Waterbury          40350.0     42000.0
# 5252  2017-01-05  2017         NaN         388450.0    560000.0
# 5253  2017-01-05  2017         NaN         164710.0    179900.0
# 5254  2017-01-06  2017     Norwalk         222030.0    375000.0
# 5255  2017-01-06  2017  Bridgeport         173780.0    215000.0
# ...          ...   ...         ...              ...         ...
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9996  2022-09-30  2022  Bridgeport         109820.0    340000.0
# 9997  2022-09-30  2022   Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
# 9999  2022-09-30  2022     Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 5251   Three Family         Triplex          6              6       2076.0
# ...

# %%
q7 = data_file[(data_file.num_rooms == 3) & (data_file.num_bathrooms == 3)]
q7
# Out:
#             Date  Year    Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009   Waterbury         111440.0    185000.0
# 7     2009-01-02  2009   Greenwich         592760.0    920000.0
# 13    2009-01-03  2009   Greenwich        1046920.0    600000.0
# 16    2009-01-05  2009   Waterbury          74620.0    206500.0
# 22    2009-01-08  2009         NaN        1260560.0   1895000.0
# ...          ...   ...         ...              ...         ...
# 9989  2022-09-29  2022    Stamford         373530.0    485000.0
# 9990  2022-09-30  2022         NaN         352030.0    700000.0
# 9991  2022-09-30  2022     Norwalk         344270.0    512500.0
# 9995  2022-09-30  2022  Bridgeport         153660.0    322000.0
# 9998  2022-09-30  2022         NaN         216420.0    415000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
q8 = data_file[(data_file.num_rooms == 3) | (data_file.num_bathrooms == 3)]
q8
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009      Waterbury         111440.0    185000.0
# 1     2009-01-02  2009     Bridgeport         124670.0    150000.0
# 2     2009-01-02  2009      Waterbury          55720.0    140000.0
# 3     2009-01-02  2009     Bridgeport        4775276.0    272900.0
# 4     2009-01-02  2009     Bridgeport         112351.0    210000.0
# ...          ...   ...            ...              ...         ...
# 9993  2022-09-30  2022  West Hartford         121870.0    235000.0
# 9995  2022-09-30  2022     Bridgeport         153660.0    322000.0
# 9997  2022-09-30  2022      Waterbury          83210.0    170000.0
# 9998  2022-09-30  2022            NaN         216420.0    415000.0
# 9999  2022-09-30  2022        Norwalk         154920.0    196000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
q9_1 = data_file[data_file.Locality == 'Greenwich']
q9_1
# Out:
#             Date  Year   Locality  Estimated Value  Sale Price       Property  \
# 5     2009-01-02  2009  Greenwich        2868880.0   3300000.0  Single Family
# 7     2009-01-02  2009  Greenwich         592760.0    920000.0  Single Family
# 13    2009-01-03  2009  Greenwich        1046920.0    600000.0  Single Family
# 21    2009-01-05  2009  Greenwich        1162140.0   1990000.0  Single Family
# 41    2009-01-16  2009  Greenwich        1692810.0   2750000.0  Single Family
# ...          ...   ...        ...              ...         ...            ...
# 9953  2022-09-17  2022  Greenwich        1740200.0   2400000.0  Single Family
# 9969  2022-09-23  2022  Greenwich        3591700.0   5000000.0  Single Family
# 9982  2022-09-28  2022  Greenwich         439320.0    865000.0  Single Family
# 9983  2022-09-28  2022  Greenwich        3570000.0   3600000.0  Single Family
# 9985  2022-09-28  2022  Greenwich        2114170.0   1985000.0  Single Family
#
# ...

# %%
q9_2 = q9_1[data_file.num_rooms == 3]
q9_3 = q9_2[data_file.Face.isin(['North', 'East'])]
q9_3
# Out:
# /tmp/ipykernel_32158/3626978130.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q9_2 = q9_1[data_file.num_rooms == 3]
# /tmp/ipykernel_32158/3626978130.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   q9_3 = q9_2[data_file.Face.isin(['North', 'East'])]
#             Date  Year   Locality  Estimated Value  Sale Price       Property  \
# 5     2009-01-02  2009  Greenwich        2868880.0   3300000.0  Single Family
# 7     2009-01-02  2009  Greenwich         592760.0    920000.0  Single Family
# 21    2009-01-05  2009  Greenwich        1162140.0   1990000.0  Single Family
# 43    2009-01-17  2009  Greenwich        1471050.0   2345000.0  Single Family
# 50    2009-01-19  2009  Greenwich        4252150.0   7850000.0  Single Family
# ...          ...   ...        ...              ...         ...            ...
# 9883  2022-09-02  2022  Greenwich         931910.0   1000100.0  Single Family
# ...

# %%
q10 = data_file.Date
l = []
# for x in data_file.index:
type(q10)
for x in q10:
  if '-08-' in x:
    l.append(x)
len(l)
l
# Out:
# ['2009-08-01',
#  '2009-08-01',
#  '2009-08-01',
#  '2009-08-01',
#  '2009-08-01',
#  '2009-08-01',
#  '2009-08-02',
#  '2009-08-02',
#  '2009-08-02',
#  '2009-08-02',
#  '2009-08-02',
#  '2009-08-02',
#  '2009-08-02',
#  '2009-08-03',
#  '2009-08-03',
#  '2009-08-03',
#  '2009-08-03',
#  '2009-08-03',
#  '2009-08-03',
#  '2009-08-03',
#  '2009-08-06',
#  '2009-08-06',
#  '2009-08-06',
#  '2009-08-07',
#  '2009-08-07',
#  '2009-08-07',
#  '2009-08-07',
#  '2009-08-08',
#  '2009-08-08',
#  '2009-08-09',
#  '2009-08-09',
#  '2009-08-09',
#  '2009-08-09',
#  '2009-08-09',
#  '2009-08-09',
#  '2009-08-09',
#  '2009-08-10',
#  '2009-08-13',
#  '2009-08-15',
#  '2009-08-15',
#  '2009-08-16',
#  '2009-08-16',
#  '2009-08-16',
#  '2009-08-17',
#  '2009-08-17',
#  '2009-08-17',
#  '2009-08-20',
#  '2009-08-20',
#  '2009-08-20',
#  '2009-08-21',
#  '2009-08-21',
#  '2009-08-21',
#  '2009-08-21',
#  '2009-08-21',
#  '2009-08-22',
#  '2009-08-22',
#  '2009-08-22',
#  '2009-08-23',
# ...

# %%
waterbury = data_file[data_file.Locality == 'Waterbury']
Bridgeport = data_file[data_file.Locality == 'Bridgeport']
Greenwich = data_file

# %%
group_by = data_file.groupby('Locality')
print(type(group_by.indices))
print(group_by.ngroups)
l = []
for name, entires in group_by:
  print('name:', name)
  avg = entires['Sale Price'].mean()
  l.append(avg)
  print(avg)
max(l)
# Out:
# <class 'dict'>
# 7
# name: Bridgeport
# 174095.33940774488
# name: Fairfield
# 727722.4806694561
# name: Greenwich
# 2270223.5394952386
# name: Norwalk
# 559095.8680981596
# name: Stamford
# 630531.275212064
# name: Waterbury
# 106215.15789473684
# name: West Hartford
# 338547.1652654109
# 2270223.5394952386
