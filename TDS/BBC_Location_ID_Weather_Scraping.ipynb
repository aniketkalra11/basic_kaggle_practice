# %% [markdown]
# # Notebook for extracting the weather information from BBC weather website

# %%
import os

import requests
import json

from urllib.parse import urlencode
import numpy as np
import pandas as pd
import re

# %%
test_city = "bengaluru"
location_url = "https://weather-broker-cdn.api.bbci.co.uk/en/maps/forecasts-observations?locations=1277333"

# %%
result = requests.get(location_url).json()
result
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '1277333',
#    'geometry': {'type': 'Point', 'coordinates': [77.59369, 12.97194]},
#    'properties': {'observations': [{'time': {'utc': '2023-10-07T19:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-07T20:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
# ...

# %%
def getlocid(city:str) -> str:
  city = city.lower()
  location_url = "https://weather-broker-cdn.api.bbci.co.uk/en/maps/forecasts-observations" + urlencode({
    'api_key': 'something'
  })
  return location_url

# %%
irvine_url = 'https://www.bbc.com/weather/2646032'
# requests.get(irvine_url).json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/BS/jupyterLab/jupitor_notebook/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
import requests

# Set the Nominatim API endpoint
url = "https://nominatim.openstreetmap.org/search"

# Set the query parameters
params = {"q": "Salem", "format": "json"}

# Make the request
# response = requests.get(url, params=params)
response = requests.get(url="https://nominatim.openstreetmap.org/ui/search.html?q=Alexandria")

# Check the response status code
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Get the latitude
    latitude = data[0]["lat"]

    # Print the latitude
    print(latitude)
else:
    # Handle the error
    print("Error: {}".format(response.status_code))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/BS/jupyterLab/jupitor_notebook/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
