# %% [markdown]
# # Notebook for extracting the weather information from BBC weather website

# %%
import os

import requests
import json

from urllib.parse import urlencode
import numpy as np
import pandas as pd
import re

# %%
test_city = "bengaluru"
location_url = "https://weather-broker-cdn.api.bbci.co.uk/en/maps/forecasts-observations?locations=1277333"

# %%
result = requests.get(location_url).json()
result
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '1277333',
#    'geometry': {'type': 'Point', 'coordinates': [77.59369, 12.97194]},
#    'properties': {'observations': [{'time': {'utc': '2023-10-01T20:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-01T21:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 22, 'f': 71},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 6, 'kph': 9},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-01T22:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-01T23:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T00:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 21, 'f': 70},
#       'windDirection': {'direction': 'SW',
#        'description': 'South Westerly',
#        'directionKey': 'sw'},
#       'averageWindSpeed': {'mph': 7, 'kph': 11},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T01:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T02:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T03:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 22, 'f': 72},
#       'windDirection': {'direction': 'SW',
#        'description': 'South Westerly',
#        'directionKey': 'sw'},
#       'averageWindSpeed': {'mph': 7, 'kph': 11},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T04:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T05:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T06:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 27, 'f': 81},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 9, 'kph': 15},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T07:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T08:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T09:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 29, 'f': 83},
#       'windDirection': {'direction': 'SW',
#        'description': 'South Westerly',
#        'directionKey': 'sw'},
#       'averageWindSpeed': {'mph': 5, 'kph': 8},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T10:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T11:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T12:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 28, 'f': 82},
#       'windDirection': {'direction': 'SW',
#        'description': 'South Westerly',
#        'directionKey': 'sw'},
#       'averageWindSpeed': {'mph': 5, 'kph': 8},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T13:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}},
#      {'time': {'utc': '2023-10-02T14:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': None, 'f': None},
#       'windDirection': {'direction': '-99',
#        'description': 'Direction not available',
#        'directionKey': None},
#       'averageWindSpeed': {'mph': None, 'kph': None},
#       'maxWindGustSpeed': {'mph': None, 'kph': None}}],
#     'location': {'name': 'Bangalore', 'container': 'India'}}},
#   {'type': 'Feature',
#    'id': '1277333',
#    'geometry': {'type': 'Point', 'coordinates': [77.59369, 12.97194]},
#    'properties': {'forecasts': [{'time': {'utc': '2023-10-02T18:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 23, 'f': 73},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 7, 'kph': 11},
#       'maxWindGustSpeed': {'mph': 13, 'kph': 20}},
#      {'time': {'utc': '2023-10-02T21:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 21, 'f': 70},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 6, 'kph': 10},
#       'maxWindGustSpeed': {'mph': 11, 'kph': 18}},
#      {'time': {'utc': '2023-10-03T00:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 20, 'f': 69},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 7, 'kph': 11},
#       'maxWindGustSpeed': {'mph': 13, 'kph': 21}},
#      {'time': {'utc': '2023-10-03T03:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 23, 'f': 73},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 7, 'kph': 12},
#       'maxWindGustSpeed': {'mph': 14, 'kph': 22}},
#      {'time': {'utc': '2023-10-03T06:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 27, 'f': 81},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 8, 'kph': 13},
#       'maxWindGustSpeed': {'mph': 15, 'kph': 24}},
#      {'time': {'utc': '2023-10-03T09:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 29, 'f': 85},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 8, 'kph': 12},
#       'maxWindGustSpeed': {'mph': 14, 'kph': 22}},
#      {'time': {'utc': '2023-10-03T12:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 27, 'f': 81},
#       'windDirection': {'direction': 'WNW',
#        'description': 'West North Westerly',
#        'directionKey': 'wnw'},
#       'averageWindSpeed': {'mph': 6, 'kph': 10},
#       'maxWindGustSpeed': {'mph': 10, 'kph': 17}},
#      {'time': {'utc': '2023-10-03T15:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 25, 'f': 77},
#       'windDirection': {'direction': 'N',
#        'description': 'Northerly',
#        'directionKey': 'n'},
#       'averageWindSpeed': {'mph': 4, 'kph': 6},
#       'maxWindGustSpeed': {'mph': 8, 'kph': 13}},
#      {'time': {'utc': '2023-10-03T18:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 23, 'f': 74},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 6, 'kph': 9},
#       'maxWindGustSpeed': {'mph': 10, 'kph': 16}},
#      {'time': {'utc': '2023-10-03T21:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 21, 'f': 71},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 6, 'kph': 9},
#       'maxWindGustSpeed': {'mph': 10, 'kph': 16}},
#      {'time': {'utc': '2023-10-04T00:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 21, 'f': 69},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 6, 'kph': 9},
#       'maxWindGustSpeed': {'mph': 11, 'kph': 18}},
#      {'time': {'utc': '2023-10-04T03:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 23, 'f': 74},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 5, 'kph': 9},
#       'maxWindGustSpeed': {'mph': 11, 'kph': 18}},
#      {'time': {'utc': '2023-10-04T06:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 27, 'f': 81},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 6, 'kph': 10},
#       'maxWindGustSpeed': {'mph': 10, 'kph': 17}},
#      {'time': {'utc': '2023-10-04T09:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 30, 'f': 85},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 6, 'kph': 10},
#       'maxWindGustSpeed': {'mph': 11, 'kph': 18}},
#      {'time': {'utc': '2023-10-04T12:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 27, 'f': 81},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 4, 'kph': 7},
#       'maxWindGustSpeed': {'mph': 7, 'kph': 11}},
#      {'time': {'utc': '2023-10-04T15:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 24, 'f': 76},
#       'windDirection': {'direction': 'NE',
#        'description': 'North Easterly',
#        'directionKey': 'ne'},
#       'averageWindSpeed': {'mph': 3, 'kph': 4},
#       'maxWindGustSpeed': {'mph': 5, 'kph': 7}},
#      {'time': {'utc': '2023-10-04T18:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 23, 'f': 73},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 4, 'kph': 7},
#       'maxWindGustSpeed': {'mph': 6, 'kph': 10}},
#      {'time': {'utc': '2023-10-04T21:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 22, 'f': 71},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 5, 'kph': 8},
#       'maxWindGustSpeed': {'mph': 8, 'kph': 13}},
#      {'time': {'utc': '2023-10-05T00:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 20, 'f': 69},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 5, 'kph': 8},
#       'maxWindGustSpeed': {'mph': 8, 'kph': 13}},
#      {'time': {'utc': '2023-10-05T06:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 28, 'f': 82},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 5, 'kph': 8},
#       'maxWindGustSpeed': {'mph': 10, 'kph': 16}},
#      {'time': {'utc': '2023-10-05T12:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 28, 'f': 82},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 4, 'kph': 7},
#       'maxWindGustSpeed': {'mph': 7, 'kph': 11}},
#      {'time': {'utc': '2023-10-05T18:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 23, 'f': 74},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 6, 'kph': 9},
#       'maxWindGustSpeed': {'mph': 11, 'kph': 17}},
#      {'time': {'utc': '2023-10-06T00:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 20, 'f': 68},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 5, 'kph': 8},
#       'maxWindGustSpeed': {'mph': 9, 'kph': 14}},
#      {'time': {'utc': '2023-10-06T06:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 27, 'f': 81},
#       'windDirection': {'direction': 'W',
#        'description': 'Westerly',
#        'directionKey': 'w'},
#       'averageWindSpeed': {'mph': 5, 'kph': 9},
#       'maxWindGustSpeed': {'mph': 10, 'kph': 16}},
#      {'time': {'utc': '2023-10-06T12:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 27, 'f': 81},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 4, 'kph': 6},
#       'maxWindGustSpeed': {'mph': 5, 'kph': 8}},
#      {'time': {'utc': '2023-10-06T18:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 22, 'f': 72},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 4, 'kph': 7},
#       'maxWindGustSpeed': {'mph': 5, 'kph': 9}},
#      {'time': {'utc': '2023-10-07T00:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 20, 'f': 68},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 4, 'kph': 6},
#       'maxWindGustSpeed': {'mph': 5, 'kph': 9}},
#      {'time': {'utc': '2023-10-07T06:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 28, 'f': 82},
#       'windDirection': {'direction': 'WNW',
#        'description': 'West North Westerly',
#        'directionKey': 'wnw'},
#       'averageWindSpeed': {'mph': 3, 'kph': 5},
#       'maxWindGustSpeed': {'mph': 7, 'kph': 11}},
#      {'time': {'utc': '2023-10-07T12:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 28, 'f': 82},
#       'windDirection': {'direction': 'S',
#        'description': 'Southerly',
#        'directionKey': 's'},
#       'averageWindSpeed': {'mph': 2, 'kph': 4},
#       'maxWindGustSpeed': {'mph': 6, 'kph': 9}},
#      {'time': {'utc': '2023-10-07T18:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 23, 'f': 74},
#       'windDirection': {'direction': 'SE',
#        'description': 'South Easterly',
#        'directionKey': 'se'},
#       'averageWindSpeed': {'mph': 2, 'kph': 3},
#       'maxWindGustSpeed': {'mph': 4, 'kph': 7}},
#      {'time': {'utc': '2023-10-08T00:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 20, 'f': 68},
#       'windDirection': {'direction': 'WSW',
#        'description': 'West South Westerly',
#        'directionKey': 'wsw'},
#       'averageWindSpeed': {'mph': 3, 'kph': 4},
#       'maxWindGustSpeed': {'mph': 6, 'kph': 10}},
#      {'time': {'utc': '2023-10-08T06:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 28, 'f': 83},
#       'windDirection': {'direction': 'ESE',
#        'description': 'East South Easterly',
#        'directionKey': 'ese'},
#       'averageWindSpeed': {'mph': 2, 'kph': 3},
#       'maxWindGustSpeed': {'mph': 5, 'kph': 8}},
#      {'time': {'utc': '2023-10-08T12:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 28, 'f': 82},
#       'windDirection': {'direction': 'S',
#        'description': 'Southerly',
#        'directionKey': 's'},
#       'averageWindSpeed': {'mph': 2, 'kph': 4},
#       'maxWindGustSpeed': {'mph': 6, 'kph': 9}},
#      {'time': {'utc': '2023-10-08T18:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 23, 'f': 74},
#       'windDirection': {'direction': 'SE',
#        'description': 'South Easterly',
#        'directionKey': 'se'},
#       'averageWindSpeed': {'mph': 3, 'kph': 5},
#       'maxWindGustSpeed': {'mph': 5, 'kph': 7}},
#      {'time': {'utc': '2023-10-09T00:00:00Z',
#        'timezone': 'Asia/Kolkata',
#        'offset': '+05:30'},
#       'temperature': {'c': 21, 'f': 69},
#       'windDirection': {'direction': 'SSW',
#        'description': 'South South Westerly',
#        'directionKey': 'ssw'},
#       'averageWindSpeed': {'mph': 3, 'kph': 4},
#       'maxWindGustSpeed': {'mph': 5, 'kph': 8}}],
#     'location': {'name': 'Bangalore', 'container': 'India'}}}]}

# %%
def getlocid(city:str) -> str:
  city = city.lower()
  location_url = "https://weather-broker-cdn.api.bbci.co.uk/en/maps/forecasts-observations" + urlencode({
    'api_key': 'something'
  })
  return location_url
